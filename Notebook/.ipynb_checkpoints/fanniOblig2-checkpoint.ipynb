# %%
#Do the following:

#1. Pick one use case (defined below).
#2. Explore and research which algorithm would work best for this use case (regression or classification)
#3. Document your findings in a file (3-5 lines) on why you chose this algorithm.
#4. Train the algorithm using Python
#5. Keep the solution as simple as possible. We are not looking for the best machine learning algorithm. 
#   We are interested in seeing that you know how to work with machine learning.
#6. Publish the code on GitHub and send us the link

# %%
# Predict passenger data for Ruter Use the same data set given to you in assignment 1. 
# I want you to make a prediction algorithm which predicts the number of passengers on
# a specific date for a specific bus (pick any one). Input should be date and output will
# be number of passengers.
# You should also show the prediction percentage score. Data file: Ruter_data.csv

# %%
# Why did you choose this algorithm?

# We decided that we would use Regression in this use case, more spesific the linear regressin algorithm.
# We choose this algorithm because it is used to predict a continuous value. Just like in the example we can predict age prediction, number of passanger/costumers, Prediction of price of an oil.
# Generally used for prediction, forecasting, time series modeling, and determining the causal effect between variables.
# In this case we are curoius about the number of passangers, so we try to find the best fit line so we can predict the output more accurately.
# I choose linear regression because it describes a relationship between two quantities that show a constant rate of change.

# %%
# Imports 
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import datetime as dt
from sklearn import metrics
from sklearn import preprocessing
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
url = "https://raw.githubusercontent.com/umaimehm/Intro_to_AI_2021/main/assignment2-machinelearning/Ruter-data.csv"
df = pd.read_csv(url, sep=";")

df.head()
# Out:
#                              TurId        Dato  Fylke Område Kommune  \
# 0  15006-2020-08-10T10:24:00+02:00  10/08/2020  Viken   Vest   Bærum
# 1  15002-2020-08-15T12:54:00+02:00  15/08/2020  Viken   Vest   Bærum
# 2  15004-2020-08-03T09:54:00+02:00  03/08/2020  Viken   Vest   Bærum
# 3  15003-2020-07-27T13:00:00+02:00  27/07/2020  Viken   Vest   Bærum
# 4  15002-2020-08-27T07:15:00+02:00  27/08/2020  Viken   Vest   Bærum
#
#                   Holdeplass_Fra                        Holdeplass_Til  \
# 0                    Nordliveien                             Tjernsmyr
# 1               Nadderud stadion  Bekkestua bussterminal (Plattform C)
# 2               Ringstabekkveien                               Skallum
# 3                      Gruvemyra                              Gullhaug
# 4  Lysaker stasjon (Plattform A)                             Tjernsmyr
#
#   Linjetype Linjefylke Linjenavn  Linjeretning  \
# 0     Lokal      Viken       150             0
# 1     Lokal      Viken       150             0
# 2     Lokal      Viken       150             0
# 3     Lokal      Viken       150             1
# 4     Lokal      Viken       150             1
#
#   Tidspunkt_Faktisk_Ankomst_Holdeplass_Fra  \
# 0                                 10:53:53
# 1                                 13:12:20
# 2                                 10:18:56
# 3                                 13:52:04
# 4                                 07:34:13
#
#   Tidspunkt_Faktisk_Avgang_Holdeplass_Fra  \
# 0                                10:53:59
# 1                                13:12:26
# 2                                10:19:21
# 3                                13:52:26
# 4                                07:34:53
#
#   Tidspunkt_Planlagt_Ankomst_Holdeplass_Fra  \
# 0                                  10:53:00
# 1                                  13:12:00
# 2                                  10:19:00
# 3                                  13:51:00
# 4                                  07:33:00
#
#   Tidspunkt_Planlagt_Avgang_Holdeplass_Fra  Kjøretøy_Kapasitet  \
# 0                                 10:53:00                 112
# 1                                 13:12:00                 112
# 2                                 10:19:00                 112
# 3                                 13:51:00                 112
# 4                                 07:33:00                 112
#
#    Passasjerer_Ombord
# 0                   5
# 1                   5
# 2                   6
# 3                  10
# 4                  10

# %%
#corrMatrix is the variable where you saved the correlation matrix
corrMatrix = df.corr()
#Standard corr plot
plt.matshow(corrMatrix)
plt.show()

#Another style of corr plot
corrMatrix.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_eedc5_row0_col0, #T_eedc5_row1_col1, #T_eedc5_row2_col2 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_eedc5_row0_col1, #T_eedc5_row0_col2, #T_eedc5_row2_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_eedc5_row1_col0 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_eedc5_row1_col2 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_eedc5_row2_col1 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_eedc5_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Linjeretning</th>
#       <th class="col_heading level0 col1" >Kjøretøy_Kapasitet</th>
#       <th class="col_heading level0 col2" >Passasjerer_Ombord</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_eedc5_level0_row0" class="row_heading level0 row0" >Linjeretning</th>
#       <td id="T_eedc5_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_eedc5_row0_col1" class="data row0 col1" >0.020337</td>
#       <td id="T_eedc5_row0_col2" class="data row0 col2" >-0.042414</td>
#     </tr>
#     <tr>
#       <th id="T_eedc5_level0_row1" class="row_heading level0 row1" >Kjøretøy_Kapasitet</th>
#       <td id="T_eedc5_row1_col0" class="data row1 col0" >0.020337</td>
#       <td id="T_eedc5_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_eedc5_row1_col2" class="data row1 col2" >0.129959</td>
#     </tr>
#     <tr>
#       <th id="T_eedc5_level0_row2" class="row_heading level0 row2" >Passasjerer_Ombord</th>
#       <td id="T_eedc5_row2_col0" class="data row2 col0" >-0.042414</td>
#       <td id="T_eedc5_row2_col1" class="data row2 col1" >0.129959</td>
#       <td id="T_eedc5_row2_col2" class="data row2 col2" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
df["Passasjerer_Ombord"] = np.where(df["Passasjerer_Ombord"] < 0, 0, df["Passasjerer_Ombord"])

#df = df.loc[df['Linjenavn'] == '150']

#df.insert(2, 'Måned', pd.to_datetime(df['Dato']).d)    # MÅNED
#df.insert(3, 'År', pd.to_datetime(df['Dato']).dt.year)   # ÅR

#df['Dato'] = pd.to_datetime(df['Dato'], format='%d/%m/%Y')   # DAG
#df['DatoOrdinal'] = df['Dato'].map(dt.datetime.toordinal)
#df['DatoFromOrdinal'] = df['DatoOrdinal'].map(dt.datetime.fromordinal)

df['Dato'] = pd.to_datetime(df['Dato'], dayfirst=True)
df
# Out:
#                                 TurId       Dato  Fylke    Område     Kommune  \
# 0     15006-2020-08-10T10:24:00+02:00 2020-08-10  Viken      Vest       Bærum
# 1     15002-2020-08-15T12:54:00+02:00 2020-08-15  Viken      Vest       Bærum
# 2     15004-2020-08-03T09:54:00+02:00 2020-08-03  Viken      Vest       Bærum
# 3     15003-2020-07-27T13:00:00+02:00 2020-07-27  Viken      Vest       Bærum
# 4     15002-2020-08-27T07:15:00+02:00 2020-08-27  Viken      Vest       Bærum
# ...                               ...        ...    ...       ...         ...
# 5995  10001-2020-06-10T15:10:00+02:00 2020-06-10  Viken   Nordøst  Lillestrøm
# 5996  10010-2020-06-23T05:54:00+02:00 2020-06-23  Viken   Nordøst  Lillestrøm
# 5997   2007-2020-06-11T17:22:00+02:00 2020-06-11   Oslo  Indre By      Sagene
# 5998  10004-2020-08-13T04:59:00+02:00 2020-08-13   Oslo  Indre By  Gamle Oslo
# 5999  34013-2020-08-05T13:31:00+02:00 2020-08-05  Viken   Nordøst  Lillestrøm
#
#                               Holdeplass_Fra  \
# 0                                Nordliveien
# 1                           Nadderud stadion
# 2                           Ringstabekkveien
# 3                                  Gruvemyra
# 4              Lysaker stasjon (Plattform A)
# ...                                      ...
# 5995                          Brauterkrysset
# 5996                              Vestbygata
# 5997      Torshovparken  (mot Torshovparken)
# 5998  Harald Hårdrådes plass  (mot Grønland)
# 5999                                Tandberg
#
#                             Holdeplass_Til Linjetype Linjefylke Linjenavn  \
# 0                                Tjernsmyr     Lokal      Viken       150
# 1     Bekkestua bussterminal (Plattform C)     Lokal      Viken       150
# 2                                  Skallum     Lokal      Viken       150
# 3                                 Gullhaug     Lokal      Viken       150
# 4                                Tjernsmyr     Lokal      Viken       150
# ...                                    ...       ...        ...       ...
# 5995                          Nordsnoveien     Lokal      Viken       100
# 5996                        Bjørnsons gate     Lokal      Viken       100
# 5997             Torshov  (mot Bentsebrua)     Lokal       Oslo        20
# 5998             Oslo gate  (mot Grønland)     Lokal      Viken       100
# 5999                                Selmer     Lokal      Viken       340
#
#       Linjeretning Tidspunkt_Faktisk_Ankomst_Holdeplass_Fra  \
# 0                0                                 10:53:53
# 1                0                                 13:12:20
# 2                0                                 10:18:56
# 3                1                                 13:52:04
# 4                1                                 07:34:13
# ...            ...                                      ...
# 5995             1                                 16:23:18
# 5996             0                                 06:00:32
# 5997             1                                 17:42:43
# 5998             0                                 06:00:11
# 5999             1                                 13:52:44
#
#      Tidspunkt_Faktisk_Avgang_Holdeplass_Fra  \
# 0                                   10:53:59
# 1                                   13:12:26
# 2                                   10:19:21
# 3                                   13:52:26
# 4                                   07:34:53
# ...                                      ...
# 5995                                16:23:48
# 5996                                06:00:40
# 5997                                17:43:10
# 5998                                06:00:23
# 5999                                13:52:48
#
#      Tidspunkt_Planlagt_Ankomst_Holdeplass_Fra  \
# 0                                     10:53:00
# 1                                     13:12:00
# 2                                     10:19:00
# 3                                     13:51:00
# 4                                     07:33:00
# ...                                        ...
# 5995                                  16:10:00
# 5996                                  05:59:00
# 5997                                  17:32:00
# 5998                                  05:59:00
# 5999                                  13:50:00
#
#      Tidspunkt_Planlagt_Avgang_Holdeplass_Fra  Kjøretøy_Kapasitet  \
# 0                                    10:53:00                 112
# 1                                    13:12:00                 112
# 2                                    10:19:00                 112
# 3                                    13:51:00                 112
# 4                                    07:33:00                 112
# ...                                       ...                 ...
# 5995                                 16:10:00                 151
# 5996                                 05:59:00                 151
# 5997                                 17:32:00                 106
# 5998                                 05:59:00                 151
# 5999                                 13:50:00                 105
#
#       Passasjerer_Ombord
# 0                      5
# 1                      5
# 2                      6
# 3                     10
# 4                     10
# ...                  ...
# 5995                   2
# 5996                   2
# 5997                   3
# 5998                   5
# 5999                   0
#
# [6000 rows x 17 columns]

# %%
df = df.loc[df['Linjenavn'] == '100']
ax1 = df.plot(kind='scatter', x='Dato', y='Passasjerer_Ombord', color='r')

#ax2 = df.plot(kind='scatter', x='Måned', y='Passasjerer_Ombord', color='g')

# %%
df2 = df[['Linjenavn','Passasjerer_Ombord', 'Dato']].copy()
df2 = df2.loc[df['Linjenavn'] == '100']
ax1 = df2.plot(kind='scatter', x='Dato', y='Passasjerer_Ombord', color='r')
df2
# Out:
#      Linjenavn  Passasjerer_Ombord       Dato
# 38         100                   1 2020-08-09
# 42         100                   0 2020-08-18
# 43         100                   7 2020-07-20
# 46         100                  13 2020-07-04
# 51         100                   0 2020-07-22
# ...        ...                 ...        ...
# 5990       100                   6 2020-08-22
# 5993       100                   5 2020-08-30
# 5995       100                   2 2020-06-10
# 5996       100                   2 2020-06-23
# 5998       100                   5 2020-08-13
#
# [465 rows x 3 columns]

# %%
df2 = df2.groupby(['Dato']).sum('Passasjerer_Ombord')
df2.groupby(['Dato']).sum('Passasjerer_Ombord').plot()
df2
# Out:
#             Passasjerer_Ombord
# Dato
# 2020-06-01                  17
# 2020-06-02                  38
# 2020-06-03                  50
# 2020-06-04                  66
# 2020-06-05                  10
# ...                        ...
# 2020-08-26                  77
# 2020-08-27                  42
# 2020-08-28                  40
# 2020-08-29                  17
# 2020-08-30                  21
#
# [90 rows x 1 columns]

# %%
df['Dato'] = pd.to_datetime(df['Dato'], format='%d/%m/%Y') 
df['DatoOrdinal'] = df['Dato'].map(dt.datetime.toordinal)
# Out:
# /var/folders/rk/c8yp4nxd1qb7mykwdynz76m00000gn/T/ipykernel_2905/3396745850.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Dato'] = pd.to_datetime(df['Dato'], format='%d/%m/%Y')
# /var/folders/rk/c8yp4nxd1qb7mykwdynz76m00000gn/T/ipykernel_2905/3396745850.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['DatoOrdinal'] = df['Dato'].map(dt.datetime.toordinal)

# %%
X = pd.DataFrame(df['DatoOrdinal']) #Var1
y = pd.DataFrame(df['Passasjerer_Ombord']) #Result

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)
linear_regressor = LinearRegression()  # create object for the class
linear_regressor.fit(X_train, y_train)  # perform linear regression
Y_pred = linear_regressor.predict(X_train)  # make predictions

# %%
plt.scatter(X_train, y_train)
plt.plot(X_train, Y_pred, color='red')
plt.show()
print( "MSE = "+str(metrics.mean_squared_error(y_train,Y_pred)))
# Out:
# MSE = 54.153548401219744

# %%
Y_pred = linear_regressor.predict(X_test)  # Predict the model on X_test
plt.scatter(X_test, y_test)
plt.plot(X_test, Y_pred, color='red')
plt.show()
print( "MSE = "+str(metrics.mean_squared_error(y_test,Y_pred)))
# Out:
# MSE = 66.60242873834189

# %%
linear_regressor.predict([[95*63]]) #Expected output = 62.46
# Out:
# array([[-6281.83827367]])

# %%
#Make a new column for Var1 * Var3
#df["Combined"] = df["DatoOrdinal"]*df["Passasjerer_Ombord"]
#Set X to the combined set
X = pd.DataFrame(df["DatoOrdinal"])
#Y to result
y = pd.DataFrame(df["Passasjerer_Ombord"])
#And make sets for Var1 and Var2
X1 = pd.DataFrame(df["DatoOrdinal"])
X2 = pd.DataFrame(df["Passasjerer_Ombord"])

#And lets do the same for the test set
Xt = pd.DataFrame(df['DatoOrdinal'])
Yt = pd.DataFrame(df['Passasjerer_Ombord'])

#Put the data in list, so we can test the different sets in a for loop
dataSet = [X,X1,X2]
trainingSet = [Xt]

# %%
linear_regressor.fit(X, y)
Y_pred = linear_regressor.predict(X)  # make predictions
plt.scatter(X, y)
plt.plot(X, Y_pred, color='red')
plt.show()

# %%
fig, ax = plt.subplots(3, figsize=(15, 15)) #Figsize ( lenght, height )
models = [] #List to save the different model for later use
caps = [ "DatoOrdinal", "Passasjerer_Ombord"] #Caption for the plots
MSE = [] #list to save mean square error
for i in range(4):  
    linear_regressor = LinearRegression()  # create object for the class
    linear_regressor.fit(trainingSet[i], Yt)  # perform linear regression
    Y_pred = linear_regressor.predict(dataSet[i])  # make predictions
    ax[i].scatter(dataSet[i], y) #Plot blue dots from test set
    ax[i].plot(dataSet[i], Y_pred, color='red') #Plot predicted from train
    err=metrics.mean_squared_error(y,Y_pred)
    ax[i].set_xlabel(caps[i] + " MSE = " +str(err )) #Set caption
    ax[i].set_ylabel("Y") #Set y lable
    MSE.append(err) #Calculate and save mse for model
    models.append(linear_regressor) #Save
fig.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/folders/rk/c8yp4nxd1qb7mykwdynz76m00000gn/T/ipykernel_2905/153227691.py in <module>
#       5 for i in range(4):
#       6     linear_regressor = LinearRegression()  # create object for the class
# ----> 7     linear_regressor.fit(trainingSet[i], Yt)  # perform linear regression
#       8     Y_pred = linear_regressor.predict(dataSet[i])  # make predictions
#       9     ax[i].scatter(dataSet[i], y) #Plot blue dots from test set
#
# IndexError: list index out of range
